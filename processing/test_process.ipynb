# %%
import os

# Affiche le répertoire courant
current_directory = os.getcwd()
print("Répertoire courant :", current_directory)
# Out:
# Répertoire courant : /Users/NDAO028930/Documents/docs/mmi/parcours data engineer/projets/JobMarket/processing

# %%
import sys
sys.path.append('../')

import pandas as pd
from tqdm import tqdm
tqdm.pandas()  # Initialiser tqdm pour pandas
from common.utils import translate_french_to_english
from common.utils import clean_text
import pickle
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 from tqdm import tqdm
#       6 tqdm.pandas()  # Initialiser tqdm pour pandas
# ----> 7 from common.utils import translate_french_to_english
#       8 from common.utils import clean_text
#       9 import pickle
#
# File ~/Documents/docs/mmi/parcours data engineer/projets/JobMarket/processing/../common/utils.py:12
#       9 #from pyspark.sql import DataFrame
#      10 import pickle
# ---> 12 from configs.conf import es
#      13 from elasticsearch.helpers import bulk
#      15 import re
#
# ModuleNotFoundError: No module named 'configs.conf'

# %%
import json
import pprint

#print(len(final_jobs))
#final_jobs.describe
#160188 jobs
#1890 companies
#final_jobs.head()

#print(final_jobs.columns.tolist())

jobs_full = pd.read_pickle('../outputs/final/jobs.pkl')
pd.set_option('display.max_columns', None)
jobs_full.head()

#['job_title', 'contract_time', 'company_name', 'salary_min', 'salary_max', 'publication_datetime', 'location', 'industry', 'offer_link', 'source', 'levels', 'category', 'contents', 'publication_time', 'publication_date', 'contract_type', 'country', 'state', 'city', 'postcode', 'latitude', 'longitude', 'currency_name', 'job_description', 'type_contract', 'addressCountry']



#jobs_json = json.dumps(json.loads(jobs_full.to_json(orient="records")))
#json_data = jobs_full.to_json(orient='records')

#pprint.pprint(json_data, compact=True)
# Out:
#                                            job_title  contract_time  \
# 0    Conseiller financier H/F - Gambetta Paris 75...      full_time
# 1    ALTERNANT CHARGE DE FORMATION (F/H) - MARSEILLE     contractor
# 2  Assistant(e) Administratif(ve) & ADV Alternanc...     contractor
# 3   Customer Success Manager Junior - Alternance ...     contractor
# 4                              Data & Cloud Engineer  not available
#
#                      company_name  salary_min  salary_max  \
# 0  CAISSE D'EPARGNE ILE-DE-FRANCE         0.0         0.0
# 1   BANQUE POPULAIRE MÉDITERRANÉE         0.0         0.0
# 2                       EVERTRUST         0.0         0.0
# 3                  KAROS MOBILITY         0.0         0.0
# 4                       DATAROOTS         0.0         0.0
#
#    publication_datetime   location                     industry  \
# 0  2024-08-07T15:10:52Z      Paris                not available
# 1  2024-07-29T07:57:13Z  Marseille                not available
# 2  2024-08-19T14:03:42Z      Paris                not available
# 3  2024-07-29T12:28:28Z   Toulouse                not available
# 4  2024-10-25T23:39:13Z     Leuven  Vacatures Ander of Algemeen
#
#                                           offer_link  source         levels  \
# 0  https://www.welcometothejungle.com/en/companie...    Wttj  not available
# 1  https://www.welcometothejungle.com/en/companie...    Wttj  not available
# 2  https://www.welcometothejungle.com/en/companie...    Wttj  not available
# 3  https://www.welcometothejungle.com/en/companie...    Wttj  not available
# 4  https://www.adzuna.be/details/4914340286?utm_m...  adzuna  not available
#
#                       category  \
# 0                not available
# 1                not available
# 2                not available
# 3                not available
# 4  Vacatures Ander of Algemeen
#
#                                      job_description publication_time  \
# 0  Position and missionsWhat is expected of you: ...         15:10:52
# 1  Position and missionsWe are looking for a work...         07:57:13
# 2  Job Description: Join our dynamic team as an A...         14:03:42
# 3  Integrated into the Success team, in charge of...         12:28:28
# 4   The Job At Dataroots , we lead the charge in ...         23:39:13
#
#   publication_date                contract_type                      country  \
# 0       2024-08-07                    permanent                       France
# 1       2024-07-29  work study(12 to 24 months)                       France
# 2       2024-08-19        work study(12 months)                       France
# 3       2024-07-29        work study(12 months)                       France
# 4       2024-10-25                not available  België / Belgique / Belgien
#
#                         state       city postcode   latitude  longitude  \
# 0               Île-de-France      Paris    75020  48.865042   2.398929
# 1  Provence-Alpes-Côte d'Azur  Marseille    13008  43.274812   5.390436
# 2               Île-de-France      Paris    75009  48.877446   2.328415
# 3                   Occitanie   Toulouse    31400  43.591238   1.446731
# 4              Vlaams-Brabant     Leuven     3000  50.879202   4.701168
#
#   currency_name country_code codeIso_lvl4 lang  Quality_of_Life_Index  \
# 0          Euro           fr       FR-IDF   en                  132.0
# 1          Euro           fr       FR-PAC   en                  132.0
# 2          Euro           fr       FR-IDF   en                  132.0
# 3          Euro           fr       FR-OCC   en                  132.0
# 4          Euro           be       BE-VLG   en                  148.4
#
#    Purchasing_Power_Index  Safety_Index  Health_Care_Index  \
# 0                    97.5          42.3               77.3
# 1                    97.5          34.1               77.3
# 2                    97.5          42.3               77.3
# 3                    97.5          50.4               77.3
# 4                   105.0          47.9               73.6
#
#    Cost_of_Living_Index  Rent_Index  Groceries_Index  Crime_Index  \
# 0                  73.6        40.5             80.1         57.7
# 1                  73.6        40.5             80.1         65.9
# 2                  73.6        40.5             80.1         57.7
# 3                  73.6        40.5             80.1         49.6
# 4                  66.6        29.0             66.2         52.1
#
#    Climate_Index  Pollution_Index  Traffic_Index  Affordability_Index
# 0           88.4        64.500000          152.5                 0.80
# 1           88.4        71.600000          152.5                 1.15
# 2           88.4        64.500000          152.5                 0.80
# 3           88.4        62.566667          152.5                 1.15
# 4           83.8        60.300000          147.8                 2.00

# %%
print(len(jobs_full))
# Out:
# 123447

# %%
import pprint, json
jobs_full_title = jobs_full[jobs_full["job_title"] == "Photographer"]

jobs_full_country = jobs_full[jobs_full["country"].str.upper() == "AUSTRALIA"]



jobs_full_country_json = jobs_full_country.to_json(orient='records')

#parsed = json.load(jobs_full_country_json)


#print(jobs_full_country_json)

#print(jobs_full_country)

jobs_full_country.head()
# Out:
#                                             job_title contract_time  \
# 10   Join Our Team This Christmas Travel Registere...     full_time
# 11   Join Us as a Connected Care Implementation Sp...     full_time
# 12   Join the Goodna Salvos and Be a Part of Somet...     part_time
# 13   Join the Salvation Army Family Store at Macka...     part_time
# 33  $150/hr or 70% of Billings - VR GP - DPA Repla...     part_time
#
#             company_name  salary_min  salary_max  publication_datetime  \
# 10  HEALTHCARE AUSTRALIA         0.0         0.0  2024-10-24T02:45:52Z
# 11        THE CX EMBASSY    100000.0         0.0  2024-11-07T03:16:41Z
# 12    THE SALVATION ARMY         0.0         0.0  2024-11-09T20:54:44Z
# 13    THE SALVATION ARMY         0.0         0.0  2024-07-31T07:17:54Z
# 33        HEALTHCARELINK        36.0      1800.0  2024-07-03T10:08:22Z
#
#                      location                     industry  \
# 10         Sydney CBD, Sydney    Healthcare & Nursing Jobs
# 11          The Rocks, Sydney                      IT Jobs
# 12                  Australia  Hospitality & Catering Jobs
# 13  Mackay Region, Queensland                  Retail Jobs
# 33   St Albans, Brimbank Area    Healthcare & Nursing Jobs
#
#                                            offer_link  source         levels  \
# 10  https://www.adzuna.com.au/details/4911325314?u...  adzuna  not available
# 11  https://www.adzuna.com.au/details/4928480589?u...  adzuna  not available
# 12  https://www.adzuna.com.au/details/4932487746?u...  adzuna  not available
# 13  https://www.adzuna.com.au/details/4801303730?u...  adzuna  not available
# 33  https://www.adzuna.com.au/details/4763423263?u...  adzuna  not available
#
#                        category  \
# 10    Healthcare & Nursing Jobs
# 11                      IT Jobs
# 12  Hospitality & Catering Jobs
# 13                  Retail Jobs
# 33    Healthcare & Nursing Jobs
#
#                                       job_description publication_time  \
# 10   Exciting Christmas Opportunity: Travel Regist...         02:45:52
# 11  Transform healthcare with digital solutions Le...         03:16:41
# 12  ABOUT US The Salvation Army is a Christian mov...         20:54:44
# 13  Start your mission volunteer experience with T...         07:17:54
# 33  About the Opportunity A bulk billing family cl...         10:08:22
#
#    publication_date  contract_type    country            state        city  \
# 10       2024-10-24  not available  Australia  New South Wales      Sydney
# 11       2024-11-07      permanent  Australia  New South Wales      Sydney
# 12       2024-11-09  not available  Australia        Not found   Not found
# 13       2024-07-31  not available  Australia       Queensland  Caboolture
# 33       2024-07-03      permanent  Australia        Not found   Not found
#
#      postcode   latitude   longitude      currency_name country_code  \
# 10       2000 -33.874726  151.205362  Australian Dollar           au
# 11       2000 -33.859992  151.208322  Australian Dollar           au
# 12  Not found -24.776109  134.755000  Australian Dollar           au
# 13       4510 -27.072664  152.955924  Australian Dollar           au
# 33  Not found   0.000000    0.000000  Australian Dollar           au
#
#    codeIso_lvl4 lang  Quality_of_Life_Index  Purchasing_Power_Index  \
# 10       AU-NSW   en                 179.70                   118.5
# 11       AU-NSW   en                 179.70                   118.5
# 12        AU-NT   en                 188.35                   125.1
# 13       AU-QLD   en                 188.35                   125.1
# 33         None   en                 188.35                   125.1
#
#     Safety_Index  Health_Care_Index  Cost_of_Living_Index  Rent_Index  \
# 10       65.9000               74.8             73.400000   51.500000
# 11       65.9000               74.8             73.400000   51.500000
# 12       58.2625               73.0             29.400000    8.300000
# 13       58.2625               73.0             72.333333   38.416667
# 33       58.2625               73.0             29.400000    8.300000
#
#     Groceries_Index  Crime_Index  Climate_Index  Pollution_Index  \
# 10        79.900000      34.1000      97.100000        28.600000
# 11        79.900000      34.1000      97.100000        28.600000
# 12        28.600000      41.7375      93.816667        26.314286
# 13        77.733333      41.7375      93.816667        26.314286
# 33        28.600000      41.7375      93.816667        26.314286
#
#     Traffic_Index  Affordability_Index
# 10     192.500000             0.800000
# 11     192.500000             0.800000
# 12     180.116667             0.900000
# 13     180.116667             1.383333
# 33     180.116667             0.900000

# %%
import json
pd.set_option('display.max_columns', None)

companies_full = pd.read_pickle('../outputs/final/companies.pkl')
#companies_full['ingest_date'] = pd.Timestamp.now()
#companies_full.head()

companies_full['ingest_date'] = pd.Timestamp.now().isoformat()


companies_full_json = companies_full.to_json(orient='records')
companies_json_records = json.loads(companies_full_json)

companies_full.head()

#companies_full.describe()

#print(companies_full_json)
# Out:
#   name_company   twitter_link              company_website publication_date  \
# 0    .becoming  not available  https://becoming-group.com/              NaT
# 1    .becoming  not available  https://becoming-group.com/              NaT
# 2    .becoming  not available  https://becoming-group.com/              NaT
# 3    .becoming  not available  https://becoming-group.com/              NaT
# 4    .becoming  not available  https://becoming-group.com/              NaT
#
#             size           logo locations industries  \
# 0  not available  not available      None       None
# 1  not available  not available      None       None
# 2  not available  not available      None       None
# 3  not available  not available      None       None
# 4  not available  not available      None       None
#
#                                             url_jobs source  \
# 0  https://www.welcometothejungle.com/en/companie...   wttj
# 1  https://www.welcometothejungle.com/en/companie...   wttj
# 2  https://www.welcometothejungle.com/en/companie...   wttj
# 3  https://www.welcometothejungle.com/en/companie...   wttj
# 4  https://www.welcometothejungle.com/en/companie...   wttj
#
#                                      linkedin_link  facebook_link  \
# 0  https://www.linkedin.com/company/becomingfrance  Not Available
# 1  https://www.linkedin.com/company/becomingfrance  Not Available
# 2  https://www.linkedin.com/company/becomingfrance  Not Available
# 3  https://www.linkedin.com/company/becomingfrance  Not Available
# 4  https://www.linkedin.com/company/becomingfrance  Not Available
#
#                           instagram_link creation_date nb_employee  \
# 0  https://instagram.com/becoming_france
# 1  https://instagram.com/becoming_france
# 2  https://instagram.com/becoming_france
# 3  https://instagram.com/becoming_france
# 4  https://instagram.com/becoming_france
#
#   parity_women parity_men avg_age_employees ca  \
# 0
# 1
# 2
# 3
# 4
#
#                                             contents country     state  \
# 0  '.becoming is a Consulting and Communication c...  Italia  Piemonte
# 1  '.becoming is a Consulting and Communication c...  Italia  Piemonte
# 2  '.becoming is a Consulting and Communication c...  Italia  Piemonte
# 3  '.becoming is a Consulting and Communication c...  Italia  Piemonte
# 4  '.becoming is a Consulting and Communication c...  Italia  Piemonte
#
#       city postcode   latitude  longitude currency_name country_code  \
# 0  Unknown  Unknown  44.933143   7.540121          Euro           it
# 1  Unknown  Unknown  44.933143   7.540121          Euro           it
# 2  Unknown  Unknown  44.933143   7.540121          Euro           it
# 3  Unknown  Unknown  44.933143   7.540121          Euro           it
# 4  Unknown  Unknown  44.933143   7.540121          Euro           it
#
#   codeIso_lvl4        clef_doublons  Quality_of_Life_Index  \
# 0        IT-21  .becoming None None             131.366667
# 1        IT-21  .becoming None None             131.366667
# 2        IT-21  .becoming None None             134.900000
# 3        IT-21  .becoming None None             193.300000
# 4        IT-21  .becoming None None             131.366667
#
#    Purchasing_Power_Index  Safety_Index  Health_Care_Index  \
# 0               74.833333         51.84          67.033333
# 1               74.833333         51.84          67.033333
# 2               42.800000         40.60          51.800000
# 3              135.200000         63.30          74.500000
# 4               74.833333         48.40          67.033333
#
#    Cost_of_Living_Index  Rent_Index  Groceries_Index  Crime_Index  \
# 0                60.575       26.65             60.5        48.16
# 1                60.575       26.65             60.5        48.16
# 2                31.700       10.60             30.1        59.40
# 3                67.900       36.50             74.3        36.70
# 4                60.575       26.65             60.5        51.60
#
#    Climate_Index  Pollution_Index  Traffic_Index  Affordability_Index  \
# 0      89.166667             74.6     128.666667               0.1000
# 1      89.166667             78.6     128.666667               1.1375
# 2      99.000000             30.0     131.700000               0.4000
# 3      98.100000             28.5     184.100000               1.3000
# 4      89.166667             84.0     128.666667               1.1375
#
#                   ingest_date
# 0  2024-11-30T22:42:23.169117
# 1  2024-11-30T22:42:23.169117
# 2  2024-11-30T22:42:23.169117
# 3  2024-11-30T22:42:23.169117
# 4  2024-11-30T22:42:23.169117

# %%
from elasticsearch import Elasticsearch


es = Elasticsearch(
    [{'host': 'localhost', 'port': 9200, 'scheme': 'https'}],
    http_auth=('elastic', 'datascientest'), 
    timeout=600,
    verify_certs=True,  # Check SSL certificats
    ca_certs='../elasticsearch/ca/ca.crt'  # Specify CA certificat path

)
# Out:
# /var/folders/w6/9qrmchcn28s3syftxypy_wgr0000gq/T/ipykernel_5728/2679775649.py:4: DeprecationWarning: The 'timeout' parameter is deprecated in favor of 'request_timeout'
#   es = Elasticsearch(
# /var/folders/w6/9qrmchcn28s3syftxypy_wgr0000gq/T/ipykernel_5728/2679775649.py:4: DeprecationWarning: The 'http_auth' parameter is deprecated. Use 'basic_auth' or 'bearer_auth' parameters instead
#   es = Elasticsearch(

# %%
#Create index in needed
if not es.indices.exists(index="bigdata-jobs"):
   es.indices.create(index="bigdata-jobs")

# %%
#Create index in needed
if not es.indices.exists(index="bigdata-companies"):
   es.indices.create(index="bigdata-companies")

# %%
from elasticsearch.helpers import bulk

import pandas as pd
import json

#jobs_full['latitude'] = jobs_full['latitude'].replace('Not found', '0').astype(float)
#jobs_full['longitude'] = jobs_full['longitude'].replace('Not found', '0').astype(float)

#jobs_full['geo_loc'] = jobs_full['latitude'] + ',' + jobs_full['longitude']




jobs_full_json = jobs_full.to_json(orient='records')

json_records = json.loads(jobs_full_json)

index_name = 'bigdata-jobs'
doctype = 'census_record'


action_list = []
for row in json_records:
    record ={
        '_op_type': 'index',
        '_index': index_name,
        '_source': row,
        '_id': row['offer_link']

    }
    action_list.append(record)
bulk(es, action_list)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[11], line 34
#      31     action_list.append(record)
#      32 bulk(es, action_list)
# ---> 34 es.indices.refresh(index='bigdata-jobs-new')
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/utils.py:446, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     443         except KeyError:
#     444             pass
# --> 446 return api(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/indices.py:3464, in IndicesClient.refresh(self, index, allow_no_indices, error_trace, expand_wildcards, filter_path, human, ignore_unavailable, pretty)
#    3462     __query["pretty"] = pretty
#    3463 __headers = {"accept": "application/json"}
# -> 3464 return self.perform_request(  # type: ignore[return-value]
#    3465     "POST",
#    3466     __path,
#    3467     params=__query,
#    3468     headers=__headers,
#    3469     endpoint_id="indices.refresh",
#    3470     path_parts=__path_parts,
#    3471 )
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:423, in NamespacedClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     410 def perform_request(
#     411     self,
#     412     method: str,
#    (...)
#     421     # Use the internal clients .perform_request() implementation
#     422     # so we take advantage of their transport options.
# --> 423     return self._client.perform_request(
#     424         method,
#     425         path,
#     426         params=params,
#     427         headers=headers,
#     428         body=body,
#     429         endpoint_id=endpoint_id,
#     430         path_parts=path_parts,
#     431     )
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:352, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     349         except (ValueError, KeyError, TypeError):
#     350             pass
# --> 352     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     353         message=message, meta=meta, body=resp_body
#     354     )
#     356 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     357 if not self._verified_elasticsearch:
#     358     # If the header is set we mark the server as verified.
#
# NotFoundError: NotFoundError(404, 'index_not_found_exception', 'no such index [bigdata-jobs-new]', bigdata-jobs-new, index_or_alias)

# %%
es.indices.refresh(index='bigdata-jobs')
# Out:
# ObjectApiResponse({'_shards': {'total': 2, 'successful': 2, 'failed': 0}})

# %%
result = es.search(
 index='bigdata-jobs',
  query={
    'match': {'country': 'australia'}
  }
 )

result['hits']['hits']
# Out:
# [{'_index': 'bigdata-jobs',
#   '_id': 'R_FuT5MB8Ass5H8EmQ9a',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'Bid Director - Expression of Interest',
#    'contract_time': 'not available',
#    'company_name': 'Siemens',
#    'salary_min': 0,
#    'salary_max': 0,
#    'publication_datetime': '2023-05-22T23:37:03Z',
#    'location': "'Sydney, Australia'",
#    'industry': 'not available',
#    'offer_link': 'https://www.themuse.com/jobs/siemens/bid-director-expression-of-interest-d7c630',
#    'source': 'TheMuse',
#    'levels': 'Mid Level',
#    'category': 'Project Management',
#    'contents': None,
#    'publication_time': '23:37:03',
#    'publication_date': '2023-05-22',
#    'contract_type': 'external',
#    'country': 'Australia',
#    'state': 'New South Wales',
#    'city': 'Sydney',
#    'postcode': '2000',
#    'latitude': -33.8698439,
#    'longitude': 151.2082848,
#    'currency_name': 'Australian Dollar',
#    'job_description': "<p>At Siemens Mobility, we empower transport providers worldwide to realize sustainable mobility solutions. As a leading technology company, we combine the real and digital worlds like no other in rail. In an open ecosystem, we bring together rolling stock, rail infrastructure, customer service, and software to enable sustainable, comfortable and cost-effective rail traffic today.<br><br>We are seeking expressions of interest for a <strong>Bid Director </strong>for potential future opportunity based in <strong>Melbourne or Sydney.</strong><br><br><strong>Your Role - Impactful, Meaningful and Future-Oriented</strong><br><br>In your role as Bid Director, you will have the overall responsibility and accountability for the assigned project throughout the entire acquisition phase until contract signature and will lead the entire project bid team.<br><br><ul><li>You will be responsible for the technical implications of T&amp;Cs, contractual set-up with third parties within a very complex PPP structure.</li><li>You will also be responsible for the on-schedule, cost-optimized and quality-compliant completion of all technical aspects of this complex turnkey bid project.</li><li>You will define and manage the project capture plan (winning strategy) as well as target pricing.</li><li>Next to this, you will lead the Limit of Authority (LoA) process and that all risks are identified and mitigated.</li><li>You will prepare and negotiate partnering agreements (NDA's, MoU's and Consortium Agreements) together with your Commercial Bid Director and all technical related matters, terms and conditions (T&amp;Cs) with customers in alignment with the regional CEO.</li><li>In addition, you will manage all internal and external stakeholders to ensure an efficient communication.</li></ul><br><strong>Join us in creating a better tomorrow with your qualifications.</strong><br><br><ul><li>You hold a completed university master's degree in electrical or mechanical engineering or comparable educational background.</li><li>Next to this, you bring in long-term professional experience in international sales, bid and project management involving highly complex turnkey infrastructure projects, preferably in the rail business.</li><li>You gained experience within the Turnkey bids.</li><li>Profound knowledge of project management processes and a clear understanding of pricing, costing methods and strategies to win customer projects as well as broad technical knowledge on different systems of Mobility business is mandatory.</li><li>Furthermore, you bring along extensive experience of managing international teams and dealing with multiple internal and external partners in an intercultural environment.</li></ul><br><strong>A better tomorrow starts with how we transform mobility today.</strong><br><br>Please be aware this is an Expression of Interest and not an advertisement for current vacancies.<br><br><strong>Why you'll love working for Siemens Mobility<br><br></strong><br><br>We live and foster an ownership culture in which every employee takes personal responsibility for our Company's success. We invest in our team members, offering a wide variety of development opportunities. Below some of the other benefits we offer to our employees:<br><br><ul><li>Flexible working arrangements</li><li>National &amp; International opportunities</li><li>Positive, inclusive and relaxed working environment</li><li>Industry leading parental leave package.</li><li>Novated leasing available</li><li>Employee discount program</li><li>Siemens Share Options</li></ul><br><strong>Siemens prides itself on its diverse workforce.</strong><br><br>Siemens has been recognised as ahead of its time for many reasons, and our progressive policies is one of them. We encourage applications that reflect the diversity of the communities within which we work.<br><br>We are a proud equal opportunity employer, where we continue to push for a work environment of diversity and inclusi ...
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '3PFuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'Construction Vocational Trainer',
#    'contract_time': 'full_time',
#    'company_name': 'ATTC',
#    'salary_min': None,
#    'salary_max': None,
#    'publication_datetime': '2024-10-30T17:31:58Z',
#    'location': 'Harristown, Toowoomba',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/details/4918329798?utm_medium=api&utm_source=5af6dd44',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Teaching Jobs',
#    'contents': None,
#    'publication_time': '17:31:58',
#    'publication_date': '2024-10-30',
#    'contract_type': 'permanent',
#    'country': 'Australia',
#    'state': 'Queensland',
#    'city': 'Toowoomba',
#    'postcode': '4350',
#    'latitude': -27.579791,
#    'longitude': 151.9260553808,
#    'currency_name': 'Australian Dollar',
#    'job_description': 'Construction Vocational Trainer At the Australian Trade Training College, we believe trades are the backbone of our society and we’re on a mission to empower students with the skills and knowledge they need to excel in their trade careers. Due to recent growth, we are in need of engaging, motivating Trainers to continue the great work in developing our future leaders in trade. As the demand for Industry Apprentices continues to grow, opportunities within Australian Trade Training College are ab…',
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '3fFuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'Speech Pathologist',
#    'contract_time': 'full_time',
#    'company_name': 'Neta Care Holistic Health Services Limited',
#    'salary_min': 80000.0,
#    'salary_max': 113000.0,
#    'publication_datetime': '2024-10-19T23:27:59Z',
#    'location': 'Camira, Ipswich',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/details/4907441303?utm_medium=api&utm_source=5af6dd44',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Healthcare & Nursing Jobs',
#    'contents': None,
#    'publication_time': '23:27:59',
#    'publication_date': '2024-10-19',
#    'contract_type': None,
#    'country': 'Australia',
#    'state': 'Queensland',
#    'city': 'Unknown',
#    'postcode': '4300',
#    'latitude': -27.634499,
#    'longitude': 152.9199269,
#    'currency_name': 'Australian Dollar',
#    'job_description': "Want to be part of something truly special? Join Neta Care Holistic Health Services Ltd and help us revolutionise the healthcare and support industry NCHHS specialises in Allied Health and Community services, particularly in the disability sector. Our skilled team works to improve the health and well-being of those we serve, helping them lead fulfilling, independent lives through physical therapy, mental health support, and disability services. ' A Commitment to Community ' At NCHHS, we’re dedi…",
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '3vFuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'Factory Hands Process Workers',
#    'contract_time': 'full_time',
#    'company_name': 'Skillforce Recruitment',
#    'salary_min': None,
#    'salary_max': None,
#    'publication_datetime': '2024-11-08T03:17:11Z',
#    'location': 'Perth CBD, Perth',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/details/4930055204?utm_medium=api&utm_source=5af6dd44',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Manufacturing Jobs',
#    'contents': None,
#    'publication_time': '03:17:11',
#    'publication_date': '2024-11-08',
#    'contract_type': 'contract',
#    'country': 'Australia',
#    'state': 'Western Australia',
#    'city': 'City of Perth',
#    'postcode': '6000',
#    'latitude': -31.9552998,
#    'longitude': 115.8589156,
#    'currency_name': 'Australian Dollar',
#    'job_description': 'Working on Assessing Rpaiaring and Rebuilding Stripping Skillforce Recruitment has opportunities for Factory Hand Process Workers for our Valued Client based in Welshpool . These positons are temp to perm and Dayshift and Afternoon Shift are on offer . Our client takes pride in all there employers and are a friendly team PLEASE NOTE THESE ROLES WILL NOT SUIT WORKING HOLIDAY OR STUDENT VISA HOLDERS DUE TO THE NATURE OF THE ROLES BEING TEMP TO PERM Shifts Days - Monday - Thursday 6.00:am - 2.30:p…',
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '3_FuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': "Head of Early Learning Centres I Sydney's Eastern Suburbs",
#    'contract_time': 'full_time',
#    'company_name': 'Selina Stanley Recruitment',
#    'salary_min': None,
#    'salary_max': None,
#    'publication_datetime': '2024-11-07T03:16:31Z',
#    'location': 'Bondi Junction, Eastern Suburbs',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/details/4928480451?utm_medium=api&utm_source=5af6dd44',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Consultancy Jobs',
#    'contents': None,
#    'publication_time': '03:16:31',
#    'publication_date': '2024-11-07',
#    'contract_type': 'permanent',
#    'country': 'Australia',
#    'state': 'New South Wales',
#    'city': 'Sydney',
#    'postcode': '2022',
#    'latitude': -33.8912429,
#    'longitude': 151.248455,
#    'currency_name': 'Australian Dollar',
#    'job_description': "SSR is Sydney's premier recruitment agency exclusively recruiting in management and leadership positions. Apply Today Head of Early Learning Centres ( ELC) | Sydney's Eastern Suburbs Are you an experienced leader and an operations expert in ECE who's made a meaningful impact across multiple centres? Join a growing organisation that currently operates three high-quality Early Learning Centres and is set to expand further in the future. About the role As the Head of Early Learning Centres, you’ll…",
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '4PFuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'Team Member - Capalaba Park Food Court',
#    'contract_time': None,
#    'company_name': 'KFC Australia Careers',
#    'salary_min': None,
#    'salary_max': None,
#    'publication_datetime': '2024-07-31T07:17:00Z',
#    'location': 'Capalaba, Brisbane',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/details/4801297129?utm_medium=api&utm_source=5af6dd44',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Hospitality & Catering Jobs',
#    'contents': None,
#    'publication_time': '07:17:00',
#    'publication_date': '2024-07-31',
#    'contract_type': None,
#    'country': 'Australia',
#    'state': 'Queensland',
#    'city': 'Unknown',
#    'postcode': '4157',
#    'latitude': -27.522037,
#    'longitude': 153.1918063,
#    'currency_name': 'Australian Dollar',
#    'job_description': "Company Information KFC is the world's most popular chicken restaurant chain, specializing in our famous Original Recipe® fried chicken. It all started with one cook who created a finger lickin' good recipe more than 75 years ago, a list of secret herbs and spices scratched out on the back of the door to his kitchen. That cook was Colonel Harland Sanders , of course, and today we still follow his formula for success, with real cooks breading and freshly preparing our delicious chicken by hand. …",
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '4fFuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'CTP Lawyer, 1-3 PQE',
#    'contract_time': 'full_time',
#    'company_name': 'Naimanclarke',
#    'salary_min': None,
#    'salary_max': None,
#    'publication_datetime': '2024-10-24T23:25:19Z',
#    'location': 'Brisbane CBD, Brisbane',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/details/4912384287?utm_medium=api&utm_source=5af6dd44',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Legal Jobs',
#    'contents': None,
#    'publication_time': '23:25:19',
#    'publication_date': '2024-10-24',
#    'contract_type': None,
#    'country': 'Australia',
#    'state': 'Queensland',
#    'city': 'Brisbane City',
#    'postcode': '4000',
#    'latitude': -27.466829,
#    'longitude': 153.0273743,
#    'currency_name': 'Australian Dollar',
#    'job_description': 'Job Description What’s in it for you? Flexibility work from home arrangements  leave benefits. Career progression opportunities  mentorship from industry leaders. Health & Wellbeing perks  fantastic benefits About your new employer: Our client is a leading national law firm with a strong reputation for delivering results in the insurance sector. Known for offering the best of both worlds: the resources of a large firm with the personalised culture of a boutique practice. About the role: Be part…',
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '4vFuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'Casual Registered Nurse',
#    'contract_time': 'part_time',
#    'company_name': 'NSW Government',
#    'salary_min': 70049.0,
#    'salary_max': 98351.0,
#    'publication_datetime': '2024-08-09T14:29:05Z',
#    'location': 'Sancrox, Port Macquarie',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/land/ad/4818050512?se=VPDWg22i7xGu0Moytoj2Ow&utm_medium=api&utm_source=5af6dd44&v=CA4B85C833263FEBECC76B1F3EE496E771F4A8AF',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Healthcare & Nursing Jobs',
#    'contents': None,
#    'publication_time': '14:29:05',
#    'publication_date': '2024-08-09',
#    'contract_type': 'permanent',
#    'country': 'Australia',
#    'state': 'New South Wales',
#    'city': 'Unknown',
#    'postcode': '2446',
#    'latitude': -31.4433401,
#    'longitude': 152.7852162,
#    'currency_name': 'Australian Dollar',
#    'job_description': "Remuneration : $35.33 - $49.60 per hour  casual loading  superannuation Employment Type : Casual Position Classification : Registered Nurse Location : Manning Hospital Requisition ID : REQ457912 Applications close : 15th December 2024 ( applications are reviewed on a regular basis ) Where you'll be working: Taree – a charming town situated on the banks of the Manning River – is the lively hub of the Manning Valley. This location serves as an excellent base for exploring the Valley's exquisite n…",
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '4_FuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'Account Executive, MidMarket - Melbourne',
#    'contract_time': 'full_time',
#    'company_name': 'RingCentral',
#    'salary_min': None,
#    'salary_max': None,
#    'publication_datetime': '2024-09-05T21:39:08Z',
#    'location': 'Australia',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/details/4852989457?utm_medium=api&utm_source=5af6dd44',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Sales Jobs',
#    'contents': None,
#    'publication_time': '21:39:08',
#    'publication_date': '2024-09-05',
#    'contract_type': None,
#    'country': 'Australia',
#    'state': 'Unknown',
#    'city': 'Unknown',
#    'postcode': 'Unknown',
#    'latitude': -24.7761086,
#    'longitude': 134.755,
#    'currency_name': 'Australian Dollar',
#    'job_description': 'This is a remote role but preferred location near Melbourne to accommodate on-site customer visits. Say hello to opportunities. It’s not everyday that you consider starting a new career. We’re RingCentral, and we’re happy that someone as talented as you is considering this role. First, a little about us, we’re a $2 Billion annual revenue company with double digit Annual Recurring Revenue (ARR) and a $93 Billion market opportunity in UCaaS, Contact Center and AI-powered adjacencies. We invest mo…',
#    'type_contract': None,
#    'addressCountry': None}},
#  {'_index': 'bigdata-jobs',
#   '_id': '5fFuT5MB8Ass5H8Ev6jC',
#   '_score': 2.3072658,
#   '_ignored': ['job_description.keyword'],
#   '_source': {'job_title': 'Registered Nurse - 2025 Post Graduate (Community Mental Health)',
#    'contract_time': 'full_time',
#    'company_name': 'Victorian Government',
#    'salary_min': None,
#    'salary_max': None,
#    'publication_datetime': '2024-11-14T12:25:08Z',
#    'location': 'Dennington, Warrnambool',
#    'industry': 'not available',
#    'offer_link': 'https://www.adzuna.com.au/land/ad/4938178902?se=VPDWg22i7xGu0Moytoj2Ow&utm_medium=api&utm_source=5af6dd44&v=2194CBAD4E48C921CC15F565606EA4235D5F47EB',
#    'source': 'adzuna',
#    'levels': 'not available',
#    'category': 'Graduate Jobs',
#    'contents': None,
#    'publication_time': '12:25:08',
#    'publication_date': '2024-11-14',
#    'contract_type': 'permanent',
#    'country': 'Australia',
#    'state': 'Victoria',
#    'city': 'Unknown',
#    'postcode': '3280',
#    'latitude': -38.355166,
#    'longitude': 142.4336417748,
#    'currency_name': 'Australian Dollar',
#    'job_description': 'Launch your career in mental health nursing with a 12-month Graduate Program in Community Mental Health This full-time role offers hands-on experience, expert mentorship, and specialised training in recovery-focused, trauma-informed care. Develop essential skills in assessment and therapeutic interventions in a supportive environment. About the role An exciting opportunity exists for a Graduate Registered Nurse to obtain a 12-month role within the Mental Health Services with placements within t…',
#    'type_contract': None,
#    'addressCountry': None}}]

# %%
from elasticsearch.helpers import bulk

index_name = 'bigdata-companies'
doctype = 'census_record'

#test 
action_list = []

#        '_id': row[key_column],
for row in companies_json_records:
    record ={
        '_op_type': 'index',
        '_index': index_name,
        '_source': row
    }
    action_list.append(record)
bulk(es,action_list)
# Out:
# (8468, [])

# %%
from elasticsearch.helpers import bulk
import time

if not es.indices.exists(index="bigdata-companies"):
   es.indices.create(index="bigdata-companies")

# Function to chunk the DataFrame into smaller batches
def chunk_dataframe(df, chunk_size=1000):
    # Yield chunks of the DataFrame
    for start in range(0, df.shape[0], chunk_size):
        yield df.iloc[start:start + chunk_size]

#Write DF in Elasticsearch
def generate_data_to_elk(df: pd.DataFrame):
    for index, row in df.iterrows():
        yield {
            "_index": "bigdata-companies", 
            #"_id": row["id"],  #specify unique value as key
            "_source": row.to_dict(),
        }

def insert_data_elk(df: pd.DataFrame):
    #Insert DataFrame in Elasticsearch
    actions = []  # List to hold batch actions
    for chunk in chunk_dataframe(df):
        for doc in generate_data_to_elk(chunk):
            actions.append(doc)
        try:
            # Convert DataFrame and insert in Elasticsearch
            #success, failed = bulk(es, generate_data_to_elk(df))
            success, failed = bulk(es, actions)
            print(f"Successfully indexed {success} documents")
            print(f"Failed to index {failed} documents.")
            actions.clear() 
            time.sleep(30)


        except Exception as e:
            print(f"Error: {e}")



insert_data_elk(companies_full)

es.indices.refresh(index='bigdata-companies')
# Out:
# Successfully indexed 1000 documents
# Failed to index [] documents.
# Error: 251 document(s) failed to index.

# %%
import glob
raw_path = '../outputs/raw/'
files_linkedin = pd.read_pickle('../outputs/raw/companies_linkedin_nov_5.pkl')

#files_linkedin = glob.glob(f'{raw_path}*companies_linkedin*.pkl')
#companies_linkedin = pd.concat([pd.read_pickle(file) for file in files_linkedin], axis=0)
files_linkedin[files_linkedin.company_name =='Meta']
# Out:
#    company_name                                company_description  \
# 20         Meta  SIHAT HOME offre des services de consultations...
#
#                                       company_website    company_industries  \
# 20  https://info.danielshealth.com/l/984121/2022-1...  Software Development
#
#          company_size                         company_associated_members  \
# 20  10,001+ employees  LinkedIn members who’ve listed Sihat Home as t...
#
#       company_location company_creation_date company_specialities  \
# 20  Roaring Spring, PA                  2016                 None
#
#                                         company_links    source  \
# 20  https://www.linkedin.com/company/meta?trk=publ...  linkedin
#
#                   ingest_date
# 20 2024-11-13 13:50:46.621730

# %%
#python3.11 -m pip install --upgrade pip
#pip3 install geopy
#pip3 install mpu
# Out:
#   Cell In[57], line 3
#     pip3 install mpu
#          ^
# SyntaxError: invalid syntax

# %%
from geopy.geocoders import Nominatim
import pycountry
import mpu

# Provide a unique and descriptive user_agent
geolocator = Nominatim(user_agent="my_geolocation_app_v1.0")
location = geolocator.geocode("El Paso, El Paso County")
print(location.address)

print((location.latitude, location.longitude))

latitude = str(location.latitude)
longitude = str(location.longitude)

location_reverse = geolocator.reverse(latitude+","+longitude)
address = location_reverse.raw['address']
print(address)

country = address.get('country', '')
print(country)

city = address.get('city', '')
print(city)

country_code = address.get('country_code', '')
print(country_code)

country_inf = pycountry.countries.get(name=country)
print(country_inf)

currency = pycountry.currencies.get(numeric=country_inf.numeric)
print(currency)
print(currency.name)
print(currency.alpha_3)




#currency = mpu.units.get_currency(country.upper)
#print(currency)

#currency = pycountry.currencies.get(letter=country.upper())
#print(country)

#location = geolocator.geocode("175 5th Avenue NYC")
#print(location.address)
# Out:
# El Paso, El Paso County, Texas, United States
# (31.7601164, -106.4870404)
# {'house_number': '299', 'road': 'East Mills Avenue', 'quarter': 'Downtown Historic District', 'city': 'El Paso', 'county': 'El Paso County', 'state': 'Texas', 'ISO3166-2-lvl4': 'US-TX', 'postcode': '79901', 'country': 'United States', 'country_code': 'us'}
# United States
# El Paso
# us
# Country(alpha_2='US', alpha_3='USA', flag='🇺🇸', name='United States', numeric='840', official_name='United States of America')
# Currency(alpha_3='USD', name='US Dollar', numeric='840')
# US Dollar
# USD

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.geocode("175 5th Avenue NYC")
print(location.address)
#Flatiron Building, 175, 5th Avenue, Flatiron, New York, NYC, New York, ...
#print((location.latitude, location.longitude))
#(40.7410861, -73.9896297241625)
#print(location.raw)
#{'place_id': '9167009604', 'type': 'attraction', ...}
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[24], line 2
#       1 from geopy.geocoders import Nominatim
# ----> 2 geolocator = Nominatim(user_agent="specify_your_app_name_here")
#       3 location = geolocator.geocode("175 5th Avenue NYC")
#       4 print(location.address)
#
# File /opt/homebrew/lib/python3.11/site-packages/geopy/geocoders/nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
#     110         'Please specify a custom `user_agent` with '
#     111         '`Nominatim(user_agent="my-application")` or by '
#     112         'overriding the default `user_agent`: '
#     113         '`geopy.geocoders.options.default_user_agent = "my-application"`.'
#     114         % self.headers['User-Agent']
#     115     )
#     117 self.api = "%s://%s%s" % (self.scheme, self.domain, self.geocode_path)
#     118 self.reverse_api = "%s://%s%s" % (self.scheme, self.domain, self.reverse_path)
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "specify_your_app_name_here" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
import os
os._exit(00)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
countries = ['be','ca','ch','de','es','fr','gb','in','it','mx','nl','nz','pl','sg','us','za']

#jobs_adzuna= pd.read_pickle('../outputs/raw/jobs_adzuna_sept.pkl')
jobs_adzuna= pd.read_pickle('../outputs/raw/jobs_adzuna_us_nov.pkl')
jobs_adzuna_test_country= pd.read_pickle('../outputs/raw/jobs_adzuna_fr_nov.pkl')

jobs_themuse = pd.read_pickle('../outputs/raw/jobs_muse_sept.pkl')
jobs_wttj = pd.read_pickle('../outputs/raw/jobs_wttj_aout.pkl')
#jobs_linkedin = pd.read_pickle('../outputs/raw/jobs_linkedin_sept.pkl')
jobs_linkedin_1 = pd.read_pickle('../outputs/raw/jobs_linkedin_sept.pkl')
jobs_linkedin_2 = pd.read_pickle('../outputs/raw/jobs_linkedin_nov.pkl')
jobs_linkedin_3 = pd.read_pickle('../outputs/raw/jobs_linkedin_nov_5.pkl')
jobs_linkedin_4 = pd.read_pickle('../outputs/raw/jobs_linkedin_nov_10.pkl')
jobs_linkedin_5 = pd.read_pickle('../outputs/raw/jobs_linkedin_nov_15.pkl')
jobs_linkedin_dup = pd.concat([jobs_linkedin_1,jobs_linkedin_2,jobs_linkedin_3,jobs_linkedin_4,jobs_linkedin_5], ignore_index=True)
jobs_linkedin = jobs_linkedin_dup.drop_duplicates()



links_linkedin = pd.read_pickle('../outputs/raw/company_links_nov_10.pkl')


companies_linkedin_1 = pd.read_pickle('../outputs/raw/companies_linkedin_nov.pkl')
companies_linkedin_2 = pd.read_pickle('../outputs/raw/companies_linkedin_nov_5.pkl')
companies_linkedin_3 = pd.read_pickle('../outputs/raw/companies_linkedin_nov_10.pkl')
companies_linkedin_4 = pd.read_pickle('../outputs/raw/companies_linkedin_nov_15.pkl')
companies_linkedin_dup = pd.concat([companies_linkedin_1,companies_linkedin_2,companies_linkedin_3,companies_linkedin_4], ignore_index=True)
companies_linkedin = companies_linkedin_dup.drop_duplicates()


#test = jobs_linkedin['company_link'].unique
#print(test)

#jobs_linkedin.head()
companies_linkedin_4.head()


print(len(jobs_linkedin))
#14650 for United States jobs
#1634 in jobs_linkedin_nov_5.pkl
#2078
#7270 all

print(len(companies_linkedin))
#69 in  companies_linkedin_nov_5.pkl
#83 in companies_linkedin_nov_10.pkl
#95 in companies_linkedin_nov_15.pkl
#256 all
