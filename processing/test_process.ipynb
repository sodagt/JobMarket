# %%
import os

# Affiche le répertoire courant
current_directory = os.getcwd()
print("Répertoire courant :", current_directory)
# Out:
# Répertoire courant : /Users/NDAO028930/Documents/docs/mmi/parcours data engineer/projets/JobMarket/processing

# %%
import sys
sys.path.append('../')

import pandas as pd
from tqdm import tqdm
tqdm.pandas()  # Initialiser tqdm pour pandas
from common.utils import translate_french_to_english
from common.utils import clean_text
import pickle
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 7
#       5 from tqdm import tqdm
#       6 tqdm.pandas()  # Initialiser tqdm pour pandas
# ----> 7 from common.utils import translate_french_to_english
#       8 from common.utils import clean_text
#       9 import pickle
#
# File ~/Documents/docs/mmi/parcours data engineer/projets/JobMarket/processing/../common/utils.py:12
#       9 #from pyspark.sql import DataFrame
#      10 import pickle
# ---> 12 from configs.conf import es
#      13 from elasticsearch.helpers import bulk
#      15 import re
#
# ModuleNotFoundError: No module named 'configs.conf'

# %%
countries = ['be','ca','ch','de','es','fr','gb','in','it','mx','nl','nz','pl','sg','us','za']

#jobs_adzuna= pd.read_pickle('../outputs/raw/jobs_adzuna_sept.pkl')
jobs_adzuna= pd.read_pickle('../outputs/raw/jobs_adzuna_us_nov.pkl')
jobs_adzuna_test_country= pd.read_pickle('../outputs/raw/jobs_adzuna_fr_nov.pkl')

jobs_themuse = pd.read_pickle('../outputs/raw/jobs_muse_sept.pkl')
jobs_wttj = pd.read_pickle('../outputs/raw/jobs_wttj_aout.pkl')
#jobs_linkedin = pd.read_pickle('../outputs/raw/jobs_linkedin_sept.pkl')
jobs_linkedin_1 = pd.read_pickle('../outputs/raw/jobs_linkedin_sept.pkl')
jobs_linkedin_2 = pd.read_pickle('../outputs/raw/jobs_linkedin_nov.pkl')
jobs_linkedin_3 = pd.read_pickle('../outputs/raw/jobs_linkedin_nov_5.pkl')
jobs_linkedin_4 = pd.read_pickle('../outputs/raw/jobs_linkedin_nov_10.pkl')
jobs_linkedin_5 = pd.read_pickle('../outputs/raw/jobs_linkedin_nov_15.pkl')
jobs_linkedin_dup = pd.concat([jobs_linkedin_1,jobs_linkedin_2,jobs_linkedin_3,jobs_linkedin_4,jobs_linkedin_5], ignore_index=True)
jobs_linkedin = jobs_linkedin_dup.drop_duplicates()



links_linkedin = pd.read_pickle('../outputs/raw/company_links_nov_10.pkl')


companies_linkedin_1 = pd.read_pickle('../outputs/raw/companies_linkedin_nov.pkl')
companies_linkedin_2 = pd.read_pickle('../outputs/raw/companies_linkedin_nov_5.pkl')
companies_linkedin_3 = pd.read_pickle('../outputs/raw/companies_linkedin_nov_10.pkl')
companies_linkedin_4 = pd.read_pickle('../outputs/raw/companies_linkedin_nov_15.pkl')
companies_linkedin_dup = pd.concat([companies_linkedin_1,companies_linkedin_2,companies_linkedin_3,companies_linkedin_4], ignore_index=True)
companies_linkedin = companies_linkedin_dup.drop_duplicates()


#test = jobs_linkedin['company_link'].unique
#print(test)

#jobs_linkedin.head()
companies_linkedin_4.head()


print(len(jobs_linkedin))
#14650 for United States jobs
#1634 in jobs_linkedin_nov_5.pkl
#2078
#7270 all

print(len(companies_linkedin))
#69 in  companies_linkedin_nov_5.pkl
#83 in companies_linkedin_nov_10.pkl
#95 in companies_linkedin_nov_15.pkl
#256 all

jobs = pd.read_pickle('../outputs/final/jobs.pkl')
final_jobs = pd.read_pickle('../outputs/final/jobs.pkl')

#final_companies = pd.read_pickle('../outputs/final/companies.pkl')


import json
import pprint

print(len(final_jobs))
final_jobs.describe
#160188 jobs
#1890 companies
#final_jobs.head()

print(final_jobs.columns.tolist())

jobs_full = jobs[['job_title', 'contract_time', 'company_name', 'salary_min', 'salary_max', 'publication_datetime', 'location', 'industry', 'offer_link', 'source', 'levels', 'category', 'contents', 'publication_time', 'publication_date', 'contract_type', 'country', 'state', 'city', 'postcode', 'latitude', 'longitude', 'currency_name', 'job_description', 'type_contract', 'addressCountry']]
jobs_full.head()

#['job_title', 'contract_time', 'company_name', 'salary_min', 'salary_max', 'publication_datetime', 'location', 'industry', 'offer_link', 'source', 'levels', 'category', 'contents', 'publication_time', 'publication_date', 'contract_type', 'country', 'state', 'city', 'postcode', 'latitude', 'longitude', 'currency_name', 'job_description', 'type_contract', 'addressCountry']



#jobs_json = json.dumps(json.loads(jobs_full.to_json(orient="records")))
#json_data = jobs_full.to_json(orient='records')

#pprint.pprint(json_data, compact=True)
# Out:
# 7270
# 256
# 160188
# ['job_title', 'contract_time', 'company_name', 'salary_min', 'salary_max', 'publication_datetime', 'location', 'industry', 'offer_link', 'source', 'levels', 'category', 'contents', 'publication_time', 'publication_date', 'contract_type', 'country', 'state', 'city', 'postcode', 'latitude', 'longitude', 'currency_name', 'job_description', 'country_adzuna', 'type_contract', 'addressCountry', 'postalCode_wttj', 'streetAdress_wttj', 'currency_wttj']
#                                            job_title contract_time  \
# 0  Storyboard Artist - Unannounced Disney Junior ...     Full-time
# 1                           Private Equity Associate     Full-time
# 2                                       Photographer     Full-time
# 3                         Coordinator, Events (Hulu)     Full-time
# 4                   Remote Sports Events Coordinator     Full-time
#
#               company_name              salary_min              salary_max  \
# 0  The Walt Disney Company  $65,000.00                          $95,000.00
# 1             HRPivot, Inc
# 2                CoCreativ
# 3  The Walt Disney Company
# 4                  LC LUXE      $30.00                              $35.00
#
#   publication_datetime          location  \
# 0           2024-11-09      Glendale, CA
# 1           2024-11-09       Chicago, IL
# 2           2024-11-09      New York, NY
# 3           2024-11-09  Santa Monica, CA
# 4           2024-11-09   Los Angeles, CA
#
#                                             industry  \
# 0                            Entertainment Providers
# 1                                Internet Publishing
# 2                               Software Development
# 3  Government Administration and Strategic Manage...
# 4                      IT Services and IT Consulting
#
#                                           offer_link    source  ...  \
# 0  https://www.linkedin.com/jobs/view/storyboard-...  linkedin  ...
# 1  https://www.linkedin.com/jobs/view/private-equ...  linkedin  ...
# 2  https://www.linkedin.com/jobs/view/photographe...  linkedin  ...
# 3  https://www.linkedin.com/jobs/view/coordinator...  linkedin  ...
# 4  https://www.linkedin.com/jobs/view/remote-spor...  linkedin  ...
#
#          country       state              city postcode    latitude  \
# 0  United States  California          Glendale    91206  34.1469416
# 1  United States    Illinois           Chicago    60604  41.8755616
# 2  United States    New York  City of New York    10000  40.7127281
# 3  United States  California      Santa Monica    90401  34.0194704
# 4  United States  California       Los Angeles    90012  34.0536909
#
#       longitude currency_name job_description type_contract addressCountry
# 0  -118.2478471     US Dollar             NaN           NaN            NaN
# 1   -87.6244212     US Dollar             NaN           NaN            NaN
# 2   -74.0060152     US Dollar             NaN           NaN            NaN
# 3   -118.491227     US Dollar             NaN           NaN            NaN
# 4   -118.242766     US Dollar             NaN           NaN            NaN
#
# [5 rows x 26 columns]

# %%
import pprint, json
jobs_full_title = jobs_full[jobs_full["job_title"] == "Photographer"]

jobs_full_country = jobs_full[jobs_full["country"].str.upper() == "AUSTRALIA"]



jobs_full_country_json = jobs_full_country.to_json(orient='records')

#parsed = json.load(jobs_full_country_json)


#print(jobs_full_country_json)

#print(jobs_full_country)

jobs_full_country.head()
# Out:
#                                  job_title  contract_time  \
# 255  Bid Director - Expression of Interest  not available
# 0       Air Force Security (No Experience)      full_time
# 3                       Restaurant Manager      full_time
# 4                       NURSE PRACTITIONER      full_time
# 7                                     Chef      full_time
#
#                             company_name salary_min salary_max  \
# 255                              Siemens          0          0
# 0                            ADF Careers    55000.0    75000.0
# 3    Spice Affair Indian cuisine Pty Ltd    65000.0    85000.0
# 4                TWINVIEW HEALTH PTY LTD    73300.0    73300.0
# 7               Parbati & Nihaal Pty Ltd    74000.0    74000.0
#
#      publication_datetime                                       location  \
# 255  2023-05-22T23:37:03Z                            'Sydney, Australia'
# 0    2024-11-01T08:51:20Z                                      Australia
# 3    2024-10-24T12:09:49Z  Canberra Region, Australian Capital Territory
# 4    2024-10-21T15:47:38Z                      Adelaide, Adelaide Region
# 7    2024-10-19T15:36:05Z                           Kadina, Copper Coast
#
#           industry                                         offer_link  \
# 255  not available  https://www.themuse.com/jobs/siemens/bid-direc...
# 0    not available  https://www.adzuna.com.au/details/4920256240?u...
# 3    not available  https://www.adzuna.com.au/details/4911795183?u...
# 4    not available  https://www.adzuna.com.au/details/4908403855?u...
# 7    not available  https://www.adzuna.com.au/details/4907094591?u...
#
#       source  ...    country            state      city postcode  \
# 255  TheMuse  ...  Australia  New South Wales    Sydney     2000
# 0     adzuna  ...  Australia          Unknown   Unknown  Unknown
# 3     adzuna  ...  Australia          Unknown  Canberra     2600
# 4     adzuna  ...  Australia  South Australia  Adelaide     5160
# 7     adzuna  ...  Australia  South Australia    Kadina     5554
#
#                 latitude           longitude      currency_name  \
# 255          -33.8698439         151.2082848  Australian Dollar
# 0            -24.7761086             134.755  Australian Dollar
# 3           -35.29024055  149.13090169070267  Australian Dollar
# 4    -35.097580050000005  138.49441649662876  Australian Dollar
# 7            -33.9647842         137.7158969  Australian Dollar
#
#                                        job_description type_contract  \
# 255  <p>At Siemens Mobility, we empower transport p...           NaN
# 0    To serve in the ADF you must be an Australian ...           NaN
# 3    Spice Affair Indian Cuisine Pty Ltd, a premier...           NaN
# 4    About TWINVIEW HEALTH We’re a South Australian...           NaN
# 7    Summary: The Parbati & Nihaal Pyt Ltd trading ...           NaN
#
#     addressCountry
# 255            NaN
# 0              NaN
# 3              NaN
# 4              NaN
# 7              NaN
#
# [5 rows x 26 columns]

# %%
import json
companies_full = pd.read_pickle('../outputs/final/companies.pkl')
#companies_full['ingest_date'] = pd.Timestamp.now()
#companies_full.head()

companies_full_json = companies_full.to_json(orient='records')
companies_json_records = json.loads(companies_full_json)

companies_full.head()

companies_full.describe()
# Out:
#        name_company   twitter_link description company_website  \
# count          1890            691        1890            1873
# unique         1841            439        1613            1788
# top            Meta  not available         TBD   Visit website
# freq              4            251         128              43
#
#             publication_date           size           logo locations  \
# count                    626           1890           1639      1521
# unique                   624             12            641       876
# top     2012-10-01T00:00:00Z  not available  not available     Paris
# freq                       3            999            999       182
#
#         industries                                      url_jobs  ...  \
# count         1521                                          1639  ...
# unique         756                                          1639  ...
# top     Technology  https://www.themuse.com/search/jobs/c-spacex  ...
# freq            97                                             1  ...
#
#         linkedin_link  facebook_link instagram_link creation_date nb_employee  \
# count            1679           1336           1378          1820        1615
# unique           1039            441            485            90         144
# top     not available  not available  not available
# freq              640            891            891           661         661
#
#          parity_women     parity_men avg_age_employees             ca contents
# count            1590           1590              1770           1356     1890
# unique             52             52                40            132     1613
# top     not available  not available     not available  not available      TBD
# freq              891            891               891            891      128
#
# [4 rows x 21 columns]

# %%
from elasticsearch import Elasticsearch


es = Elasticsearch(
    [{'host': 'localhost', 'port': 9200, 'scheme': 'https'}],
    http_auth=('elastic', 'datascientest'), 
    timeout=600,
    verify_certs=True,  # Check SSL certificats
    ca_certs='../elasticsearch/ca/ca.crt'  # Specify CA certificat path

)
# Out:
# /var/folders/w6/9qrmchcn28s3syftxypy_wgr0000gq/T/ipykernel_1986/158269660.py:4: DeprecationWarning: The 'timeout' parameter is deprecated in favor of 'request_timeout'
#   es = Elasticsearch(
# /var/folders/w6/9qrmchcn28s3syftxypy_wgr0000gq/T/ipykernel_1986/158269660.py:4: DeprecationWarning: The 'http_auth' parameter is deprecated. Use 'basic_auth' or 'bearer_auth' parameters instead
#   es = Elasticsearch(

# %%
#Create index in needed
if not es.indices.exists(index="bigdata-jobs"):
   es.indices.create(index="bigdata-jobs")

# %%
#Create index in needed
if not es.indices.exists(index="bigdata-companies"):
   es.indices.create(index="bigdata-companies")

# %%
from elasticsearch.helpers import bulk

import pandas as pd
import json

jobs_full['latitude'] = jobs_full['latitude'].replace('Not found', '0').astype(float)
jobs_full['longitude'] = jobs_full['longitude'].replace('Not found', '0').astype(float)

#jobs_full['geo_loc'] = jobs_full['latitude'] + ',' + jobs_full['longitude']




jobs_full_json = jobs_full.to_json(orient='records')

json_records = json.loads(jobs_full_json)

index_name = 'bigdata-jobs'
doctype = 'census_record'


action_list = []
for row in json_records:
    record ={
        '_op_type': 'index',
        '_index': index_name,
        '_source': row
    }
    action_list.append(record)
bulk(es, action_list)
# Out:
# /var/folders/w6/9qrmchcn28s3syftxypy_wgr0000gq/T/ipykernel_1986/3625228313.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobs_full['latitude'] = jobs_full['latitude'].replace('Not found', '0').astype(float)
# /var/folders/w6/9qrmchcn28s3syftxypy_wgr0000gq/T/ipykernel_1986/3625228313.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobs_full['longitude'] = jobs_full['longitude'].replace('Not found', '0').astype(float)
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[34], line 30
#      24     record ={
#      25         '_op_type': 'index',
#      26         '_index': index_name,
#      27         '_source': row
#      28     }
#      29     action_list.append(record)
# ---> 30 bulk(es, action_list)
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/helpers/actions.py:521, in bulk(client, actions, stats_only, ignore_status, *args, **kwargs)
#     519 # make streaming_bulk yield successful results so we can count them
#     520 kwargs["yield_ok"] = True
# --> 521 for ok, item in streaming_bulk(
#     522     client, actions, ignore_status=ignore_status, *args, **kwargs  # type: ignore[misc]
#     523 ):
#     524     # go through request-response pairs and detect failures
#     525     if not ok:
#     526         if not stats_only:
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/helpers/actions.py:436, in streaming_bulk(client, actions, chunk_size, max_chunk_bytes, raise_on_error, expand_action_callback, raise_on_exception, max_retries, initial_backoff, max_backoff, yield_ok, ignore_status, *args, **kwargs)
#     433     time.sleep(min(max_backoff, initial_backoff * 2 ** (attempt - 1)))
#     435 try:
# --> 436     for data, (ok, info) in zip(
#     437         bulk_data,
#     438         _process_bulk_chunk(
#     439             client,
#     440             bulk_actions,
#     441             bulk_data,
#     442             raise_on_exception,
#     443             raise_on_error,
#     444             ignore_status,
#     445             *args,
#     446             **kwargs,
#     447         ),
#     448     ):
#     449         if not ok:
#     450             action, info = info.popitem()
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/helpers/actions.py:339, in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, ignore_status, *args, **kwargs)
#     335     ignore_status = (ignore_status,)
#     337 try:
#     338     # send the actual request
# --> 339     resp = client.bulk(*args, operations=bulk_actions, **kwargs)  # type: ignore[arg-type]
#     340 except ApiError as e:
#     341     gen = _process_bulk_chunk_error(
#     342         error=e,
#     343         bulk_data=bulk_data,
#    (...)
#     346         raise_on_error=raise_on_error,
#     347     )
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/utils.py:446, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     443         except KeyError:
#     444             pass
# --> 446 return api(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/__init__.py:717, in Elasticsearch.bulk(self, operations, body, index, error_trace, filter_path, human, pipeline, pretty, refresh, require_alias, routing, source, source_excludes, source_includes, timeout, wait_for_active_shards)
#     712 __body = operations if operations is not None else body
#     713 __headers = {
#     714     "accept": "application/json",
#     715     "content-type": "application/x-ndjson",
#     716 }
# --> 717 return self.perform_request(  # type: ignore[return-value]
#     718     "PUT",
#     719     __path,
#     720     params=__query,
#     721     headers=__headers,
#     722     body=__body,
#     723     endpoint_id="bulk",
#     724     path_parts=__path_parts,
#     725 )
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:316, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     313 else:
#     314     target = path
# --> 316 meta, resp_body = self.transport.perform_request(
#     317     method,
#     318     target,
#     319     headers=request_headers,
#     320     body=body,
#     321     request_timeout=self._request_timeout,
#     322     max_retries=self._max_retries,
#     323     retry_on_status=self._retry_on_status,
#     324     retry_on_timeout=self._retry_on_timeout,
#     325     client_meta=self._client_meta,
#     326     otel_span=otel_span,
#     327 )
#     329 # HEAD with a 404 is returned as a normal response
#     330 # since this is used as an 'exists' functionality.
#     331 if not (method == "HEAD" and meta.status == 404) and (
#     332     not 200 <= meta.status < 299
#     333     and (
#    (...)
#     337     )
#     338 ):
#
# File /opt/homebrew/lib/python3.11/site-packages/elastic_transport/_transport.py:342, in Transport.perform_request(self, method, target, body, headers, max_retries, retry_on_status, retry_on_timeout, request_timeout, client_meta, otel_span)
#     340 try:
#     341     otel_span.set_node_metadata(node.host, node.port, node.base_url, target)
# --> 342     resp = node.perform_request(
#     343         method,
#     344         target,
#     345         body=request_body,
#     346         headers=request_headers,
#     347         request_timeout=request_timeout,
#     348     )
#     349     _logger.info(
#     350         "%s %s%s [status:%s duration:%.3fs]"
#     351         % (
#    (...)
#     357         )
#     358     )
#     360     if method != "HEAD":
#
# File /opt/homebrew/lib/python3.11/site-packages/elastic_transport/_node/_http_urllib3.py:202, in Urllib3HttpNode.perform_request(self, method, target, body, headers, request_timeout)
#     194         err = ConnectionError(str(e), errors=(e,))
#     195     self._log_request(
#     196         method=method,
#     197         target=target,
#    (...)
#     200         exception=err,
#     201     )
# --> 202     raise err from None
#     204 meta = ApiResponseMeta(
#     205     node=self.config,
#     206     duration=duration,
#    (...)
#     209     headers=response_headers,
#     210 )
#     211 self._log_request(
#     212     method=method,
#     213     target=target,
#    (...)
#     217     response=data,
#     218 )
#
# ConnectionError: Connection error caused by: ConnectionError(Connection error caused by: NewConnectionError(<elastic_transport._node._urllib3_chain_certs.HTTPSConnection object at 0x131c6b210>: Failed to establish a new connection: [Errno 61] Connection refused))

# %%
index_name = 'bigdata-companies'
doctype = 'census_record'

#test 
action_list = []

for row in companies_json_records:
    record ={
        '_op_type': 'index',
        '_index': index_name,
        '_source': row
    }
    action_list.append(record)
bulk(es,action_list)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[35], line 14
#       8     record ={
#       9         '_op_type': 'index',
#      10         '_index': index_name,
#      11         '_source': row
#      12     }
#      13     action_list.append(record)
# ---> 14 bulk(es,action_list)
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/helpers/actions.py:521, in bulk(client, actions, stats_only, ignore_status, *args, **kwargs)
#     519 # make streaming_bulk yield successful results so we can count them
#     520 kwargs["yield_ok"] = True
# --> 521 for ok, item in streaming_bulk(
#     522     client, actions, ignore_status=ignore_status, *args, **kwargs  # type: ignore[misc]
#     523 ):
#     524     # go through request-response pairs and detect failures
#     525     if not ok:
#     526         if not stats_only:
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/helpers/actions.py:436, in streaming_bulk(client, actions, chunk_size, max_chunk_bytes, raise_on_error, expand_action_callback, raise_on_exception, max_retries, initial_backoff, max_backoff, yield_ok, ignore_status, *args, **kwargs)
#     433     time.sleep(min(max_backoff, initial_backoff * 2 ** (attempt - 1)))
#     435 try:
# --> 436     for data, (ok, info) in zip(
#     437         bulk_data,
#     438         _process_bulk_chunk(
#     439             client,
#     440             bulk_actions,
#     441             bulk_data,
#     442             raise_on_exception,
#     443             raise_on_error,
#     444             ignore_status,
#     445             *args,
#     446             **kwargs,
#     447         ),
#     448     ):
#     449         if not ok:
#     450             action, info = info.popitem()
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/helpers/actions.py:339, in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, ignore_status, *args, **kwargs)
#     335     ignore_status = (ignore_status,)
#     337 try:
#     338     # send the actual request
# --> 339     resp = client.bulk(*args, operations=bulk_actions, **kwargs)  # type: ignore[arg-type]
#     340 except ApiError as e:
#     341     gen = _process_bulk_chunk_error(
#     342         error=e,
#     343         bulk_data=bulk_data,
#    (...)
#     346         raise_on_error=raise_on_error,
#     347     )
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/utils.py:446, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     443         except KeyError:
#     444             pass
# --> 446 return api(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/__init__.py:717, in Elasticsearch.bulk(self, operations, body, index, error_trace, filter_path, human, pipeline, pretty, refresh, require_alias, routing, source, source_excludes, source_includes, timeout, wait_for_active_shards)
#     712 __body = operations if operations is not None else body
#     713 __headers = {
#     714     "accept": "application/json",
#     715     "content-type": "application/x-ndjson",
#     716 }
# --> 717 return self.perform_request(  # type: ignore[return-value]
#     718     "PUT",
#     719     __path,
#     720     params=__query,
#     721     headers=__headers,
#     722     body=__body,
#     723     endpoint_id="bulk",
#     724     path_parts=__path_parts,
#     725 )
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File /opt/homebrew/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:316, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     313 else:
#     314     target = path
# --> 316 meta, resp_body = self.transport.perform_request(
#     317     method,
#     318     target,
#     319     headers=request_headers,
#     320     body=body,
#     321     request_timeout=self._request_timeout,
#     322     max_retries=self._max_retries,
#     323     retry_on_status=self._retry_on_status,
#     324     retry_on_timeout=self._retry_on_timeout,
#     325     client_meta=self._client_meta,
#     326     otel_span=otel_span,
#     327 )
#     329 # HEAD with a 404 is returned as a normal response
#     330 # since this is used as an 'exists' functionality.
#     331 if not (method == "HEAD" and meta.status == 404) and (
#     332     not 200 <= meta.status < 299
#     333     and (
#    (...)
#     337     )
#     338 ):
#
# File /opt/homebrew/lib/python3.11/site-packages/elastic_transport/_transport.py:342, in Transport.perform_request(self, method, target, body, headers, max_retries, retry_on_status, retry_on_timeout, request_timeout, client_meta, otel_span)
#     340 try:
#     341     otel_span.set_node_metadata(node.host, node.port, node.base_url, target)
# --> 342     resp = node.perform_request(
#     343         method,
#     344         target,
#     345         body=request_body,
#     346         headers=request_headers,
#     347         request_timeout=request_timeout,
#     348     )
#     349     _logger.info(
#     350         "%s %s%s [status:%s duration:%.3fs]"
#     351         % (
#    (...)
#     357         )
#     358     )
#     360     if method != "HEAD":
#
# File /opt/homebrew/lib/python3.11/site-packages/elastic_transport/_node/_http_urllib3.py:202, in Urllib3HttpNode.perform_request(self, method, target, body, headers, request_timeout)
#     194         err = ConnectionError(str(e), errors=(e,))
#     195     self._log_request(
#     196         method=method,
#     197         target=target,
#    (...)
#     200         exception=err,
#     201     )
# --> 202     raise err from None
#     204 meta = ApiResponseMeta(
#     205     node=self.config,
#     206     duration=duration,
#    (...)
#     209     headers=response_headers,
#     210 )
#     211 self._log_request(
#     212     method=method,
#     213     target=target,
#    (...)
#     217     response=data,
#     218 )
#
# ConnectionError: Connection error caused by: ConnectionError(Connection error caused by: NewConnectionError(<elastic_transport._node._urllib3_chain_certs.HTTPSConnection object at 0x35d2ca7d0>: Failed to establish a new connection: [Errno 61] Connection refused))

# %%
from elasticsearch.helpers import bulk
import time

if not es.indices.exists(index="bigdata-companies"):
   es.indices.create(index="bigdata-companies")

# Function to chunk the DataFrame into smaller batches
def chunk_dataframe(df, chunk_size=1000):
    # Yield chunks of the DataFrame
    for start in range(0, df.shape[0], chunk_size):
        yield df.iloc[start:start + chunk_size]

#Write DF in Elasticsearch
def generate_data_to_elk(df: pd.DataFrame):
    for index, row in df.iterrows():
        yield {
            "_index": "bigdata-companies", 
            #"_id": row["id"],  #specify unique value as key
            "_source": row.to_dict(),
        }

def insert_data_elk(df: pd.DataFrame):
    #Insert DataFrame in Elasticsearch
    actions = []  # List to hold batch actions
    for chunk in chunk_dataframe(df):
        for doc in generate_data_to_elk(chunk):
            actions.append(doc)
        try:
            # Convert DataFrame and insert in Elasticsearch
            #success, failed = bulk(es, generate_data_to_elk(df))
            success, failed = bulk(es, actions)
            print(f"Successfully indexed {success} documents")
            print(f"Failed to index {failed} documents.")
            actions.clear() 
            time.sleep(30)


        except Exception as e:
            print(f"Error: {e}")



insert_data_elk(companies_full)
# Out:
# Successfully indexed 1000 documents
# Failed to index [] documents.
# Error: 251 document(s) failed to index.

# %%
import glob
raw_path = '../outputs/raw/'
files_linkedin = pd.read_pickle('../outputs/raw/companies_linkedin_nov_5.pkl')

#files_linkedin = glob.glob(f'{raw_path}*companies_linkedin*.pkl')
#companies_linkedin = pd.concat([pd.read_pickle(file) for file in files_linkedin], axis=0)
files_linkedin[files_linkedin.company_name =='Meta']
# Out:
#    company_name                                company_description  \
# 20         Meta  SIHAT HOME offre des services de consultations...
#
#                                       company_website    company_industries  \
# 20  https://info.danielshealth.com/l/984121/2022-1...  Software Development
#
#          company_size                         company_associated_members  \
# 20  10,001+ employees  LinkedIn members who’ve listed Sihat Home as t...
#
#       company_location company_creation_date company_specialities  \
# 20  Roaring Spring, PA                  2016                 None
#
#                                         company_links    source  \
# 20  https://www.linkedin.com/company/meta?trk=publ...  linkedin
#
#                   ingest_date
# 20 2024-11-13 13:50:46.621730

# %%
#python3.11 -m pip install --upgrade pip
#pip3 install geopy
#pip3 install mpu
# Out:
#   Cell In[57], line 3
#     pip3 install mpu
#          ^
# SyntaxError: invalid syntax

# %%
from geopy.geocoders import Nominatim
import pycountry
import mpu

# Provide a unique and descriptive user_agent
geolocator = Nominatim(user_agent="my_geolocation_app_v1.0")
location = geolocator.geocode("El Paso, El Paso County")
print(location.address)

print((location.latitude, location.longitude))

latitude = str(location.latitude)
longitude = str(location.longitude)

location_reverse = geolocator.reverse(latitude+","+longitude)
address = location_reverse.raw['address']
print(address)

country = address.get('country', '')
print(country)

city = address.get('city', '')
print(city)

country_code = address.get('country_code', '')
print(country_code)

country_inf = pycountry.countries.get(name=country)
print(country_inf)

currency = pycountry.currencies.get(numeric=country_inf.numeric)
print(currency)
print(currency.name)
print(currency.alpha_3)




#currency = mpu.units.get_currency(country.upper)
#print(currency)

#currency = pycountry.currencies.get(letter=country.upper())
#print(country)

#location = geolocator.geocode("175 5th Avenue NYC")
#print(location.address)
# Out:
# El Paso, El Paso County, Texas, United States
# (31.7601164, -106.4870404)
# {'house_number': '299', 'road': 'East Mills Avenue', 'quarter': 'Downtown Historic District', 'city': 'El Paso', 'county': 'El Paso County', 'state': 'Texas', 'ISO3166-2-lvl4': 'US-TX', 'postcode': '79901', 'country': 'United States', 'country_code': 'us'}
# United States
# El Paso
# us
# Country(alpha_2='US', alpha_3='USA', flag='🇺🇸', name='United States', numeric='840', official_name='United States of America')
# Currency(alpha_3='USD', name='US Dollar', numeric='840')
# US Dollar
# USD

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.geocode("175 5th Avenue NYC")
print(location.address)
#Flatiron Building, 175, 5th Avenue, Flatiron, New York, NYC, New York, ...
#print((location.latitude, location.longitude))
#(40.7410861, -73.9896297241625)
#print(location.raw)
#{'place_id': '9167009604', 'type': 'attraction', ...}
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[24], line 2
#       1 from geopy.geocoders import Nominatim
# ----> 2 geolocator = Nominatim(user_agent="specify_your_app_name_here")
#       3 location = geolocator.geocode("175 5th Avenue NYC")
#       4 print(location.address)
#
# File /opt/homebrew/lib/python3.11/site-packages/geopy/geocoders/nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
#     110         'Please specify a custom `user_agent` with '
#     111         '`Nominatim(user_agent="my-application")` or by '
#     112         'overriding the default `user_agent`: '
#     113         '`geopy.geocoders.options.default_user_agent = "my-application"`.'
#     114         % self.headers['User-Agent']
#     115     )
#     117 self.api = "%s://%s%s" % (self.scheme, self.domain, self.geocode_path)
#     118 self.reverse_api = "%s://%s%s" % (self.scheme, self.domain, self.reverse_path)
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "specify_your_app_name_here" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
import os
os._exit(00)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
